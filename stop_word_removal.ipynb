# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyanshi-goyal28/NLP-programs/blob/main/stop_word_removal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# without NLTK

# %%
document = " The children are playing in the park."
stop_words = {'is','a','for','in','this'}
words=document.lower().split()
filtered_words = [word for word in words if word not in stop_words]

display(filtered_words)
# Out:
# ['the', 'children', 'are', 'playing', 'the', 'park.']

# %%
# Stop Word Removal using NLTK

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')

text = "The children are playing in the garden and they are enjoying the game"

tokens = word_tokenize(text)

stop_words = set(stopwords.words('english'))

filtered_words = [word for word in tokens if word.lower() not in stop_words]

display(filtered_words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ['children', 'playing', 'garden', 'enjoying', 'game']
