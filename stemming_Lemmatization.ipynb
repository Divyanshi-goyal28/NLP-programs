# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyanshi-goyal28/NLP-programs/blob/main/stemming_Lemmatization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Stemming and Lemmatization in NLP

import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
text="The children are running faster than their friends"

# %%
tokens=word_tokenize(text)

# %%
stemmer=PorterStemmer()

# %%
stemmed_words = [stemmer.stem(word) for word in tokens]
display(stemmed_words)
# Out:
# ['the', 'children', 'are', 'run', 'faster', 'than', 'their', 'friend']

# %%
# Lemmatization in NLP

from nltk.stem import WordNetLemmatizer


nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()

lemmatized_words = [lemmatizer.lemmatize(word) for word in tokens]

display(lemmatized_words)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ['The', 'child', 'are', 'running', 'faster', 'than', 'their', 'friend']

# %% [markdown]
# spacy

# %%
import spacy

# Load English language model
nlp = spacy.load("en_core_web_sm")
doc = nlp(text)
lemmatized_words = [token.lemma_ for token in doc]

display(lemmatized_words)
# Out:
# ['the', 'child', 'be', 'run', 'fast', 'than', 'their', 'friend']
