# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyanshi-goyal28/NLP-programs/blob/main/tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk spacy -q

import nltk
import spacy

nltk.download('punkt')
nltk.download('punkt_tab')

from nltk.tokenize import sent_tokenize, word_tokenize

text = "Natural Language Processing is interesting. It helps computers understand human language."

print("Using NLTK")

print("\nSentence Tokenization:")
print(sent_tokenize(text))

print("\nWord Tokenization:")
print(word_tokenize(text))

print("\nUsing spaCy")

nlp = spacy.blank("en")
nlp.add_pipe("sentencizer")

doc = nlp(text)

print("\nSentence Tokenization:")
print([sent.text for sent in doc.sents])

print("\nWord Tokenization:")
print([token.text for token in doc])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Using NLTK
#
# Sentence Tokenization:
# ['Natural Language Processing is interesting.', 'It helps computers understand human language.']
#
# Word Tokenization:
# ['Natural', 'Language', 'Processing', 'is', 'interesting', '.', 'It', 'helps', 'computers', 'understand', 'human', 'language', '.']
#
# Using spaCy
#
# Sentence Tokenization:
# ['Natural Language Processing is interesting.', 'It helps computers understand human language.']
#
# Word Tokenization:
# ['Natural', 'Language', 'Processing', 'is', 'interesting', '.', 'It', 'helps', 'computers', 'understand', 'human', 'language', '.']
